# %% [markdown]
# This notebook has the analysis of text fooler attack by varying different constraints

# %% [markdown]
# Cloning the Text attack code

# %%
# !git clone https://github.com/ruchasathe/TextAttack.git
# Out:
# Cloning into 'TextAttack'...
# remote: Enumerating objects: 472, done.
# remote: Counting objects: 100% (472/472), done.
# remote: Compressing objects: 100% (385/385), done.
# remote: Total 472 (delta 88), reused 466 (delta 82), pack-reused 0
# Receiving objects: 100% (472/472), 5.76 MiB | 25.00 MiB/s, done.
# Resolving deltas: 100% (88/88), done.

# %%
cd TextAttack/
# Out:
# /content/TextAttack/TextAttack

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/TextAttack/TextAttack
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#      |████████████████████████████████| 60 kB 4.3 MB/s
# ...
#      |████████████████████████████████| 401 kB 12.5 MB/s
# ...
#      |████████████████████████████████| 769 kB 79.0 MB/s
# ...
#      |████████████████████████████████| 365 kB 69.5 MB/s
# ...
#      |████████████████████████████████| 5.8 MB 69.7 MB/s
# ...
#      |████████████████████████████████| 125 kB 55.5 MB/s
# ...
#      |████████████████████████████████| 3.6 MB 70.7 MB/s
# ...

# %%
# !pip -V
# Out:
# pip 21.1.3 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)

# %% [markdown]
# Training the model

# %%
# !textattack train --model distilbert-base-uncased \
--model-num-labels 2 --model-max-length 128 --per-device-train-batch-size 16 \
--dataset imdb --num-epochs 4 --learning-rate 2e-05
# Out:
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
from google.colab import drive
drive.mount('/content/drive')

# %% [markdown]
# Tweaking edit distance between 12, 30 and 50 putting other constraints constant.

# %% [markdown]
# Edit distance set to 12

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 362.80it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# Edit distance set to 30

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^30 max-words-perturbed^max_percent=0.75 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 361.48it/s]
# ...

# %% [markdown]
# Edit distance set to 50

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^50 max-words-perturbed^max_percent=0.75 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 836.96it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_transform.bias', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# Changing max words perturbed between 0.0001, 0.01 and 0.75

# %% [markdown]
# Max words perturbed set to 0.0001

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.0001 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 420.48it/s]
# ...

# %% [markdown]
# Max words perturbed set to 0.75

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 818.29it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_transform.weight', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight', 'vocab_transform.bias']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# Max words perturbed set to 0.01

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.01 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 31.37it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_layer_norm.bias', 'vocab_projector.bias', 'vocab_transform.weight', 'vocab_transform.bias', 'vocab_projector.weight', 'vocab_layer_norm.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# Changing min_cos_sim putting other constraints constant. changing from 0.2 to 0.5 to 0.8

# %% [markdown]
# min_cos_sim set to 0.2

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle  \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.2 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 436.74it/s]
# ...

# %% [markdown]
# min_cos_Sim set to 0.5

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle --enable-advance-metrics \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.5 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 788.30it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# min_cos_Sim set to 0.8

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle  \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.8 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 412.92it/s]
# ...

# %% [markdown]
# Disabling verb_noun swap - parts of speech. this didn't give any change in the attack performance

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle  \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.8 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 473.02it/s]
# ...

# %% [markdown]
# Pre-transformation changes: inserting spaces, random character deletions

# %% [markdown]
# Before applying the transformations

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle --enable-advance-metrics \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.5 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 788.30it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# After performing the transformations

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.5 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# 2022-12-02 20:16:37.593198: E tensorflow/stream_executor/cuda/cuda_driver.cc:271] failed call to cuInit: CUDA_ERROR_NO_DEVICE: no CUDA-capable device is detected
# ...

# %% [markdown]
# Changing the search method from greedy word swap to greedy search

# %% [markdown]
# With greedy word swap

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle --enable-advance-metrics \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.5 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 788.30it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.weight', 'vocab_projector.bias', 'vocab_layer_norm.bias', 'vocab_transform.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# ...

# %% [markdown]
# With Greedy search

# %%
# !textattack attack --attack-recipe textfooler --num-examples 10 \
--model-from-huggingface distilbert-base-uncased --dataset-from-huggingface imdb \
--dataset-split test --shuffle \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 embedding^min_cos_sim=0.5 repeat stopword
# Out:
# textattack: Updating TextAttack package dependencies.
# textattack: Downloading NLTK required packages.
# [nltk_data] Downloading package averaged_perceptron_tagger to
# [nltk_data]     /root/nltk_data...
# [nltk_data]   Unzipping taggers/averaged_perceptron_tagger.zip.
# [nltk_data] Downloading package stopwords to /root/nltk_data...
# [nltk_data]   Unzipping corpora/stopwords.zip.
# [nltk_data] Downloading package omw to /root/nltk_data...
# [nltk_data] Downloading package universal_tagset to /root/nltk_data...
# [nltk_data]   Unzipping taggers/universal_tagset.zip.
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 396.06it/s]
# ...
