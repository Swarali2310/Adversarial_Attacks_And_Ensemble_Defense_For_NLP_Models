# %%
# !pip3 install textattack[tensorflow]
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...

# %%
# !textattack list models
# Out:
# albert-base-v2
# albert-base-v2-ag-news
# albert-base-v2-cola
# albert-base-v2-imdb
# albert-base-v2-mr
# albert-base-v2-qqp
# albert-base-v2-rte
# albert-base-v2-snli
# albert-base-v2-sst2
# albert-base-v2-stsb
# albert-base-v2-wnli
# albert-base-v2-yelp
# bert-base-uncased
# bert-base-uncased-ag-news
# bert-base-uncased-cola
# bert-base-uncased-imdb
# bert-base-uncased-mnli
# bert-base-uncased-mr
# bert-base-uncased-mrpc
# bert-base-uncased-qnli
# bert-base-uncased-qqp
# bert-base-uncased-rte
# bert-base-uncased-snli
# bert-base-uncased-sst2
# bert-base-uncased-stsb
# bert-base-uncased-wnli
# bert-base-uncased-yelp
# cnn-ag-news
# cnn-imdb
# cnn-mr
# cnn-sst2
# cnn-yelp
# distilbert-base-cased-cola
# distilbert-base-cased-mrpc
# distilbert-base-cased-qqp
# distilbert-base-cased-snli
# distilbert-base-cased-sst2
# distilbert-base-cased-stsb
# distilbert-base-uncased
# distilbert-base-uncased-ag-news
# distilbert-base-uncased-cola
# distilbert-base-uncased-imdb
# ...

# %%
# !textattack peek-dataset --dataset-from-huggingface imdb
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 23.68it/s]
# textattack: Loading datasets dataset imdb, split train.
# textattack: Number of samples: 25000
# textattack: Number of words per input:
# textattack: 	total:   5893057
# textattack: 	mean:    235.72
# textattack: 	std:     174.78
# textattack: 	min:     10
# textattack: 	max:     2479
# textattack: Dataset lowercased: False
# textattack: First sample:
# ...

# %%
# !textattack attack --model albert-base-v2-imdb --recipe textfooler --num-examples 10
# Out:
# ...
# Dataset imdb downloaded and prepared to /root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1. Subsequent calls will reuse this data.
# 100% 3/3 [00:00<00:00, 880.91it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: textattack/albert-base-v2-imdb
# Downloading: 100% 727/727 [00:00<00:00, 704kB/s]
# Downloading: 100% 46.7M/46.7M [00:00<00:00, 67.7MB/s]
# Downloading: 100% 25.0/25.0 [00:00<00:00, 23.5kB/s]
# Downloading: 100% 760k/760k [00:01<00:00, 666kB/s]
# Downloading: 100% 156/156 [00:00<00:00, 145kB/s]
# textattack: Downloading https://textattack.s3.amazonaws.com/word_embeddings/paragramcf.
# 100% 481M/481M [00:40<00:00, 12.0MB/s]
# textattack: Unzipping file /root/.cache/textattack/tmpg43x97yu.zip to /root/.cache/textattack/word_embeddings/paragramcf.
# textattack: Successfully saved word_embeddings/paragramcf to cache.
# ...

# %%
# !textattack train --model textattack/albert-base-v2-imdb --model-num-labels 2 --model-max-length 64 --per-device-train-batch-size 128 --dataset imdb --num-epochs 3
# Out:
# textattack: Loading transformers AutoModelForSequenceClassification: textattack/albert-base-v2-imdb
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 843.19it/s]
# textattack: Loading datasets dataset imdb, split train.
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 954.62it/s]
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 873.27it/s]
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 917.52it/s]
# ...

# %%
# !textattack eval --num-examples 1000 --model ./outputs/2022-11-14-05-05-13-095802/best_model/ --dataset-from-huggingface imdb --dataset-split test
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 671.27it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Got 1000 predictions.
# textattack: Correct 842/1000 (84.20%)

# %%
# !textattack attack --recipe textfooler --num-examples 100 --model ./outputs/2022-11-14-05-05-13-095802/best_model/ --dataset-from-huggingface imdb --dataset-split test
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 857.61it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Unknown if model of class <class 'transformers.models.albert.modeling_albert.AlbertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  delete
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.5
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
# ...

# %%
# !textattack train --model albert-base-v2 --model-num-labels 2 --model-max-length 64 --per-device-train-batch-size 128 --dataset imdb --num-epochs 3
# Out:
# textattack: Loading transformers AutoModelForSequenceClassification: albert-base-v2
# Some weights of the model checkpoint at albert-base-v2 were not used when initializing AlbertForSequenceClassification: ['predictions.decoder.weight', 'predictions.decoder.bias', 'predictions.bias', 'predictions.dense.weight', 'predictions.dense.bias', 'predictions.LayerNorm.bias', 'predictions.LayerNorm.weight']
# - This IS expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing AlbertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %%
# !textattack eval --num-examples 1000 --model ./outputs/2022-11-14-05-55-50-314003/best_model/ --dataset-from-huggingface imdb --dataset-split test
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 758.92it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Got 1000 predictions.
# textattack: Correct 858/1000 (85.80%)

# %%
# !textattack attack --recipe textfooler --num-examples 100 --model ./outputs/2022-11-14-05-55-50-314003/best_model/ --dataset-from-huggingface imdb --dataset-split test
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 853.43it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Unknown if model of class <class 'transformers.models.albert.modeling_albert.AlbertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
#     (wir_method):  delete
#   )
#   (goal_function):  UntargetedClassification
#   (transformation):  WordSwapEmbedding(
#     (max_candidates):  50
#     (embedding):  WordEmbedding
#   )
#   (constraints):
#     (0): WordEmbeddingDistance(
#         (embedding):  WordEmbedding
#         (min_cos_sim):  0.5
#         (cased):  False
#         (include_unknown_words):  True
#         (compare_against_original):  True
# ...
