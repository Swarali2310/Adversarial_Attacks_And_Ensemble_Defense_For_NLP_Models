# %%
# !git clone https://github.com/ruchasathe/TextAttack.git
# Out:
# Cloning into 'TextAttack'...
# remote: Enumerating objects: 467, done.
# remote: Counting objects: 100% (467/467), done.
# remote: Compressing objects: 100% (380/380), done.
# remote: Total 467 (delta 82), reused 467 (delta 82), pack-reused 0
# Receiving objects: 100% (467/467), 5.76 MiB | 16.81 MiB/s, done.
# Resolving deltas: 100% (82/82), done.

# %%
cd TextAttack/
# Out:
# /content/TextAttack

# %%
# !pip install .
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Processing /content/TextAttack
#   DEPRECATION: A future pip version will change local packages to be built in-place without first copying to a temporary directory. We recommend you use --use-feature=in-tree-build to test your packages with this new behavior before it becomes the default.
#    pip 21.3 will remove support for this functionality. You can find discussion regarding this at https://github.com/pypa/pip/issues/7555.
# ...
#   Using cached bert_score-0.3.12-py3-none-any.whl (60 kB)
# ...
#   Using cached flair-0.11.3-py3-none-any.whl (401 kB)
# ...
#   Using cached language_tool_python-2.7.1-py3-none-any.whl (34 kB)
# ...
#   Using cached lemminflect-0.2.3-py3-none-any.whl (769 kB)
# ...
#   Using cached lru_dict-1.1.8-cp38-cp38-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (29 kB)
# ...
#   Using cached datasets-2.4.0-py3-none-any.whl (365 kB)
# ...

# %%
# !pip -V
# Out:
# pip 21.1.3 from /usr/local/lib/python3.8/dist-packages/pip (python 3.8)

# %%
# !textattack train --model distilbert-base-uncased \
--model-num-labels 2 --model-max-length 128 --per-device-train-batch-size 16 \
--dataset imdb --num-epochs 4 --learning-rate 2e-05
# Out:
# textattack: Loading transformers AutoModelForSequenceClassification: distilbert-base-uncased
# Some weights of the model checkpoint at distilbert-base-uncased were not used when initializing DistilBertForSequenceClassification: ['vocab_transform.weight', 'vocab_layer_norm.bias', 'vocab_transform.bias', 'vocab_layer_norm.weight', 'vocab_projector.bias', 'vocab_projector.weight']
# - This IS expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model trained on another task or with another architecture (e.g. initializing a BertForSequenceClassification model from a BertForPreTraining model).
# - This IS NOT expected if you are initializing DistilBertForSequenceClassification from the checkpoint of a model that you expect to be exactly identical (initializing a BertForSequenceClassification model from a BertForSequenceClassification model).
# ...

# %% [markdown]
# Bert-finetuned on IMDB with fixed constraints: Edit distance of 12, Max words perturbed: 0.1

# %%
# !textattack attack --attack-recipe textfooler --num-examples 50 \
--model-from-huggingface Wakaka/bert-finetuned-imdb --dataset-from-huggingface imdb   \
--dataset-split test --enable-advance-metrics  \
--constraints edit-distance^12 max-words-perturbed^max_percent=0.75 repeat stopword
# Out:
# WARNING:datasets.builder:Reusing dataset imdb (/root/.cache/huggingface/datasets/imdb/plain_text/1.0.0/2fdd8b9bcadd6e7055e742a706876ba43f19faee861df134affd7a3f60fc38a1)
# 100% 3/3 [00:00<00:00, 806.65it/s]
# textattack: Loading datasets dataset imdb, split test.
# textattack: Loading pre-trained model from HuggingFace model repository: Wakaka/bert-finetuned-imdb
# Downloading: 100% 725/725 [00:00<00:00, 710kB/s]
# Downloading: 100% 433M/433M [00:38<00:00, 11.2MB/s]
# Downloading: 100% 320/320 [00:00<00:00, 294kB/s]
# Downloading: 100% 213k/213k [00:00<00:00, 237kB/s]
# Downloading: 100% 669k/669k [00:01<00:00, 591kB/s]
# Downloading: 100% 112/112 [00:00<00:00, 107kB/s]
# textattack: Unknown if model of class <class 'transformers.models.bert.modeling_bert.BertForSequenceClassification'> compatible with goal function <class 'textattack.goal_functions.classification.untargeted_classification.UntargetedClassification'>.
# Attack(
#   (search_method): GreedyWordSwapWIR(
# ...
